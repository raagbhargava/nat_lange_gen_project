# %%
# !pip3 install yake
# Out:
# Requirement already satisfied: yake in /usr/local/lib/python3.10/dist-packages (0.4.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from yake) (0.9.0)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.10/dist-packages (from yake) (8.1.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from yake) (1.23.5)
# Requirement already satisfied: segtok in /usr/local/lib/python3.10/dist-packages (from yake) (1.5.11)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from yake) (3.2.1)
# Requirement already satisfied: jellyfish in /usr/local/lib/python3.10/dist-packages (from yake) (1.0.3)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from segtok->yake) (2023.6.3)

# %%
# import libraries
import numpy as np
import pandas as pd
import torch
import yake
import json
import re

import nltk
from nltk import pos_tag, word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
import spacy
nlp = spacy.load('en_core_web_sm')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# We need 3 key words per line of poem
# So ngram size is 1 (n = 1)
# So we need top 3 words (top = 3)
# To promote diversity in words we dont want repeated words (dedupLim= 1)

algorithm = yake.KeywordExtractor(n = 1,
                                  top =3,
                                  dedupLim= 1)

# %%
file_1 ='ready_poems.csv'
file_2 ='news_summaries.csv'
file_3 ='roc.csv'

df_1 = pd.read_csv(file_1)
df_2 = pd.read_csv(file_2)
df_3 = pd.read_csv(file_3)

# %%
# Find the columns with "sentence" in the title
sentence_columns = [col for col in df_3.columns if 'sentence' in col.lower()]

# Combine the selected columns into a new column
df_3['text'] = df_3[sentence_columns].apply(lambda row: ' '.join(row), axis=1)

# %%
df_1.rename(columns={'content': 'text'}, inplace=True)
df_2.rename(columns={'headlines': 'title'}, inplace=True)
df_3.rename(columns={'storytitle': 'title'}, inplace=True)

# %%
df_1 = df_1[['title', 'text']]
df_1.head()
# Out:
#                                                title  \
# 0              Do not go gentle into that good night
# 1                    How Do I Love Thee? (Sonnet 43)
# 2  Shall I compare thee to a summer’s day? (Sonne...
# 3                                                If—
# 4                              Nothing Gold Can Stay
#
#                                                 text
# 0  do not go gentle into that good night NEWLINE ...
# 1  how do i love thee let me count the ways NEWLI...
# 2  shall i compare thee to a summers day NEWLINE ...
# 3  if you can keep your head when all about you N...
# 4  natures first green is gold NEWLINE her hardes...

# %%
df_2 = df_2[['title', 'text']]
df_2.head()
# Out:
#                                                title  \
# 0  CBI books Rajasthan CM's brother, 14 others in...
# 1  Fan shares selfie taken by SRK with his father...
# 2  European Commission recommends Ukraine be gran...
# 3  Jos Buttler smashes England's second-fastest O...
# 4  Paytm CEO Vijay Shekhar buys 1.7 lakh shares o...
#
#                                                 text
# 0  The CBI has registered a case against Rajastha...
# 1  Twitter user Rohan Mukherjee shared that his f...
# 2  The European Commission on Friday recommended ...
# 3  England's Jos Buttler on Friday smashed the se...
# 4  Paytm Founder and CEO Vijay Shekhar Sharma has...

# %%
df_3 = df_3[['title', 'text']]
df_3.head()
# Out:
#                      title                                               text
# 0   David Drops the Weight  David noticed he had put on a lot of weight re...
# 1              Frustration  Tom had a very short temper. One day a guest m...
# 2       Marcus Buys Khakis  Marcus needed clothing for a business casual e...
# 3       Different Opinions  Bobby thought Bill should buy a trailer and ha...
# 4  Overcoming shortcomings  John was a pastor with a very bad memory. He t...

# %% [markdown]
# **Generating Keywords for Dataset 1: Poetry**

# %%
titles = df_1['title']
texts = df_1['text']

# %%
def has_proper_noun(text):
    # Tokenize the text and get part-of-speech tags
    words = word_tokenize(text)
    pos_tags = pos_tag(words)

    # Check if any word is tagged as a proper noun (NNP or NNPS)
    return any(pos == 'NNP' or pos == 'NNPS' for _, pos in pos_tags)

# %%
tokens = []
count = 0
text_data = []
title_data = []
sentences = []

for sen,tit in zip(texts, titles):
    tit = re.sub(r'[^a-zA-Z\s]', '', tit)
    tit = tit.lower()
    tokenized = word_tokenize(tit)
    pos = has_proper_noun(tokenized)

    if len(tokenized) <= 2 or pos:
        continue
    try:

        sen = re.sub(r'[^a-zA-Z\s.]', '', sen)
        sen = sen.replace(' NEWLINE', '.')
        token_len = len(sen.split())
        sen_len = len(sen.split('.'))

        if 5<=sen_len<=50:
            count += 1
            tokens.append(token_len)
            text_data.append(sen)
            title_data.append(tit)
            sentences.append(sen_len)
    except:
        continue


print(count)
print('average tokens of story:', np.mean(tokens))
print('average sentences of story:', np.mean(sentences))
print('average tokens per sentence:', np.mean(tokens)/np.mean(sentences))
# Out:
# [Synset('bash.n.02'), Synset('do.n.02'), Synset('doctor_of_osteopathy.n.01'), Synset('make.v.01'), Synset('perform.v.01'), Synset('do.v.03'), Synset('do.v.04'), Synset('cause.v.01'), Synset('practice.v.01'), Synset('suffice.v.01'), Synset('do.v.08'), Synset('act.v.02'), Synset('serve.v.09'), Synset('do.v.11'), Synset('dress.v.16'), Synset('do.v.13')]
# [Synset('not.r.01')]
# [Synset('go.n.01'), Synset('adam.n.03'), Synset('crack.n.09'), Synset('go.n.04'), Synset('travel.v.01'), Synset('go.v.02'), Synset('go.v.03'), Synset('become.v.01'), Synset('go.v.05'), Synset('run.v.05'), Synset('run.v.03'), Synset('proceed.v.04'), Synset('go.v.09'), Synset('go.v.10'), Synset('sound.v.02'), Synset('function.v.01'), Synset('run_low.v.01'), Synset('move.v.13'), Synset('survive.v.01'), Synset('go.v.16'), Synset('die.v.01'), Synset('belong.v.03'), Synset('go.v.19'), Synset('start.v.09'), Synset('move.v.15'), Synset('go.v.22'), Synset('go.v.23'), Synset('blend.v.02'), Synset('go.v.25'), Synset('fit.v.02'), Synset('rifle.v.02'), Synset('go.v.28'), Synset('plump.v.04'), Synset('fail.v.04'), Synset('go.a.01')]
# [Synset('pacify.v.01'), Synset('ennoble.v.02'), Synset('gentle.v.03'), Synset('gentle.s.01'), Synset('gentle.s.02'), Synset('gentle.s.03'), Synset('aristocratic.s.01'), Synset('docile.s.03'), Synset('easy.s.05'), Synset('easy.s.08')]
# []
# []
# [Synset('good.n.01'), Synset('good.n.02'), Synset('good.n.03'), Synset('commodity.n.01'), Synset('good.a.01'), Synset('full.s.06'), Synset('good.a.03'), Synset('estimable.s.02'), Synset('beneficial.s.01'), Synset('good.s.06'), Synset('good.s.07'), Synset('adept.s.01'), Synset('good.s.09'), Synset('dear.s.02'), Synset('dependable.s.04'), Synset('good.s.12'), Synset('good.s.13'), Synset('effective.s.04'), Synset('good.s.15'), Synset('good.s.16'), Synset('good.s.17'), Synset('good.s.18'), Synset('good.s.19'), Synset('good.s.20'), Synset('good.s.21'), Synset('well.r.01'), Synset('thoroughly.r.02')]
# [Synset('night.n.01'), Synset('night.n.02'), Synset('night.n.03'), Synset('night.n.04'), Synset('night.n.05'), Synset('night.n.06'), Synset('night.n.07'), Synset('nox.n.01')]
# []
# [Synset('bash.n.02'), Synset('do.n.02'), Synset('doctor_of_osteopathy.n.01'), Synset('make.v.01'), Synset('perform.v.01'), Synset('do.v.03'), Synset('do.v.04'), Synset('cause.v.01'), Synset('practice.v.01'), Synset('suffice.v.01'), Synset('do.v.08'), Synset('act.v.02'), Synset('serve.v.09'), Synset('do.v.11'), Synset('dress.v.16'), Synset('do.v.13')]
# [Synset('iodine.n.01'), Synset('one.n.01'), Synset('i.n.03'), Synset('one.s.01')]
# [Synset('love.n.01'), Synset('love.n.02'), Synset('beloved.n.01'), Synset('love.n.04'), Synset('love.n.05'), Synset('sexual_love.n.02'), Synset('love.v.01'), Synset('love.v.02'), Synset('love.v.03'), Synset('sleep_together.v.01')]
# []
# [Synset('sonnet.n.01'), Synset('sonnet.v.01'), Synset('sonnet.v.02')]
# []
# [Synset('iodine.n.01'), Synset('one.n.01'), Synset('i.n.03'), Synset('one.s.01')]
# [Synset('comparison.n.03'), Synset('compare.v.01'), Synset('compare.v.02'), Synset('compare.v.03'), Synset('compare.v.04')]
# []
# []
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('summer.n.01'), Synset('summer.n.02'), Synset('summer.v.01')]
# [Synset('day.n.01'), Synset('day.n.02'), Synset('day.n.03'), Synset('day.n.04'), Synset('day.n.05'), Synset('day.n.06'), Synset('day.n.07'), Synset('sidereal_day.n.01'), Synset('day.n.09'), Synset('day.n.10')]
# [Synset('sonnet.n.01'), Synset('sonnet.v.01'), Synset('sonnet.v.02')]
# []
# [Synset('nothing.n.01'), Synset('nothing.r.01')]
# [Synset('gold.n.01'), Synset('amber.n.01'), Synset('gold.n.03'), Synset('gold.n.04'), Synset('gold.n.05'), Synset('gold.s.01'), Synset('aureate.s.02')]
# [Synset('can.n.01'), Synset('can.n.02'), Synset('can.n.03'), Synset('buttocks.n.01'), Synset('toilet.n.02'), Synset('toilet.n.01'), Synset('can.v.01'), Synset('displace.v.03')]
# [Synset('stay.n.01'), Synset('arrest.n.02'), Synset('stay.n.03'), Synset('stay.n.04'), Synset('stay.n.05'), Synset('stay.v.01'), Synset('stay.v.02'), Synset('bide.v.01'), Synset('stay.v.04'), Synset('stay.v.05'), Synset('stay.v.06'), Synset('persist.v.03'), Synset('last_out.v.01'), Synset('stay.v.09'), Synset('stay.v.10'), Synset('quell.v.02')]
# []
# [Synset('cipher.n.04')]
# [Synset('world_health_organization.n.01')]
# [Synset('are.n.01'), Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# []
# []
# [Synset('road.n.01'), Synset('road.n.02')]
# [Synset('not.r.01')]
# [Synset('take.v.01'), Synset('take.v.02'), Synset('lead.v.01'), Synset('take.v.04'), Synset('assume.v.03'), Synset('take.v.06'), Synset('bring.v.01'), Synset('take.v.08'), Synset('take.v.09'), Synset('choose.v.01'), Synset('accept.v.02'), Synset('fill.v.04'), Synset('consider.v.03'), Synset('necessitate.v.01'), Synset('take.v.15'), Synset('film.v.01'), Synset('remove.v.01'), Synset('consume.v.02'), Synset('take.v.19'), Synset('take.v.20'), Synset('take.v.21'), Synset('assume.v.05'), Synset('accept.v.05'), Synset('take.v.24'), Synset('learn.v.04'), Synset('claim.v.05'), Synset('take.v.27'), Synset('aim.v.01'), Synset('take.v.29'), Synset('carry.v.02'), Synset('lease.v.04'), Synset('subscribe.v.05'), Synset('take.v.33'), Synset('take.v.34'), Synset('take.v.35'), Synset('claim.v.04'), Synset('accept.v.08'), Synset('contain.v.05'), Synset('take.v.39'), Synset('drive.v.16'), Synset('take.v.41'), Synset('contract.v.04'), Synset('interpreted.s.01'), Synset('taken.s.02')]
# [Synset('on.a.01'), Synset('on.a.02'), Synset('along.r.01'), Synset('on.r.02'), Synset('on.r.03')]
# [Synset('child.n.01'), Synset('child.n.02'), Synset('child.n.03'), Synset('child.n.04')]
# [Synset('still.n.01'), Synset('hush.n.01'), Synset('still.n.03'), Synset('distillery.n.01'), Synset('calm.v.01'), Synset('hush.v.02'), Synset('still.v.03'), Synset('still.v.04'), Synset('inactive.s.10'), Synset('silent.s.01'), Synset('placid.s.01'), Synset('still.a.04'), Synset('still.a.05'), Synset('still.s.06'), Synset('still.r.01'), Synset('however.r.01'), Synset('even.r.03'), Synset('still.r.04')]
# [Synset('iodine.n.01'), Synset('one.n.01'), Synset('i.n.03'), Synset('one.s.01')]
# [Synset('rise.n.01'), Synset('rise.n.02'), Synset('ascent.n.01'), Synset('rise.n.04'), Synset('raise.n.01'), Synset('upgrade.n.04'), Synset('lift.n.04'), Synset('emanation.n.03'), Synset('rise.n.09'), Synset('advance.n.06'), Synset('rise.v.01'), Synset('rise.v.02'), Synset('arise.v.03'), Synset('rise.v.04'), Synset('surface.v.01'), Synset('originate.v.01'), Synset('ascend.v.08'), Synset('wax.v.02'), Synset('heighten.v.01'), Synset('get_up.v.02'), Synset('rise.v.11'), Synset('rise.v.12'), Synset('rise.v.13'), Synset('rebel.v.01'), Synset('rise.v.15'), Synset('rise.v.16'), Synset('resurrect.v.03')]
# []
# [Synset('raven.n.01'), Synset('raven.v.01'), Synset('raven.v.02'), Synset('devour.v.04'), Synset('raven.v.04')]
# [Synset('have.v.01'), Synset('have.v.02'), Synset('experience.v.03'), Synset('own.v.01'), Synset('get.v.03'), Synset('consume.v.02'), Synset('have.v.07'), Synset('hold.v.03'), Synset('have.v.09'), Synset('have.v.10'), Synset('have.v.11'), Synset('have.v.12'), Synset('induce.v.02'), Synset('accept.v.02'), Synset('receive.v.01'), Synset('suffer.v.02'), Synset('have.v.17'), Synset('give_birth.v.01'), Synset('take.v.35')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('coke.n.01'), Synset('coca_cola.n.01'), Synset('coke.n.03'), Synset('coke.v.01')]
# []
# []
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# []
# [Synset('song.n.01'), Synset('song.n.02'), Synset('song.n.03'), Synset('birdcall.n.01'), Synset('song.n.05'), Synset('sung.n.01')]
# []
# [Synset('tire.v.02'), Synset('tire.v.01'), Synset('aweary.s.01')]
# [Synset('blues.n.01'), Synset('blues.n.02'), Synset('blue.n.01'), Synset('blue.n.02'), Synset('blue.n.03'), Synset('blue_sky.n.01'), Synset('bluing.n.01'), Synset('amobarbital_sodium.n.01'), Synset('blue.n.07'), Synset('blue.v.01')]
# []
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('just.a.01'), Synset('equitable.a.01'), Synset('fair.a.01'), Synset('good.s.07'), Synset('merely.r.01'), Synset('precisely.r.01'), Synset('just.r.03'), Synset('just.r.04'), Synset('barely.r.01'), Synset('just.r.06')]
# []
# [Synset('say.n.01'), Synset('state.v.01'), Synset('allege.v.01'), Synset('suppose.v.01'), Synset('read.v.02'), Synset('order.v.01'), Synset('pronounce.v.01'), Synset('say.v.07'), Synset('say.v.08'), Synset('say.v.09'), Synset('say.v.10'), Synset('say.v.11')]
# [Synset('lashkar-e-taiba.n.01'), Synset('let.n.02'), Synset('let.v.01'), Synset('let.v.02'), Synset('permit.v.01'), Synset('get.v.03'), Synset('let.v.05'), Synset('lease.v.03')]
# [Synset('united_states.n.01'), Synset('america.n.02')]
# [Synset('beryllium.n.01'), Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('united_states.n.01'), Synset('america.n.02')]
# [Synset('again.r.01')]
# [Synset('morning.n.01'), Synset('good_morning.n.01'), Synset('dawn.n.01'), Synset('dawn.n.02')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# []
# [Synset('burn.v.01'), Synset('burn.v.02'), Synset('burn.v.03'), Synset('bite.v.02'), Synset('burn.v.05'), Synset('burn.v.06'), Synset('burn.v.07'), Synset('burn.v.08'), Synset('burn.v.09'), Synset('burn.v.10'), Synset('cauterize.v.01'), Synset('sunburn.v.01'), Synset('cut.v.21'), Synset('burn_off.v.01'), Synset('burn.v.15'), Synset('burned.s.01'), Synset('burned.s.02'), Synset('burned.s.03')]
# [Synset('house.n.01'), Synset('firm.n.01'), Synset('house.n.03'), Synset('house.n.04'), Synset('house.n.05'), Synset('house.n.06'), Synset('house.n.07'), Synset('sign_of_the_zodiac.n.01'), Synset('house.n.09'), Synset('family.n.01'), Synset('theater.n.01'), Synset('house.n.12'), Synset('house.v.01'), Synset('house.v.02')]
# []
# []
# [Synset('astatine.n.01'), Synset('at.n.02')]
# []
# [Synset('bat.n.01'), Synset('bat.n.02'), Synset('squash_racket.n.01'), Synset('cricket_bat.n.01'), Synset('bat.n.05'), Synset('bat.v.01'), Synset('bat.v.02'), Synset('bat.v.03'), Synset('bat.v.04'), Synset('cream.v.02')]
# [Synset('fillet.n.05'), Synset('stopping.n.02'), Synset('stop.v.01'), Synset('discontinue.v.01'), Synset('stop.v.03'), Synset('stop.v.04'), Synset('stop.v.05'), Synset('break.v.10'), Synset('check.v.18'), Synset('intercept.v.01'), Synset('end.v.01'), Synset('barricade.v.01'), Synset('hold_on.v.02')]
# [Synset('by.r.01'), Synset('aside.r.06')]
# [Synset('forest.n.01'), Synset('wood.n.01'), Synset('forest.n.01'), Synset('wood.n.03'), Synset('wood.n.04'), Synset('wood.n.05'), Synset('wood.n.06'), Synset('woodwind.n.01'), Synset('wood.n.08')]
# [Synset('on.a.01'), Synset('on.a.02'), Synset('along.r.01'), Synset('on.r.02'), Synset('on.r.03')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('white.s.04'), Synset('snow-clad.s.01'), Synset('snow-white.s.01')]
# [Synset('evening.n.01'), Synset('evening.n.02'), Synset('evening.n.03'), Synset('flush.v.04'), Synset('even.v.02'), Synset('even.v.03')]
# [Synset('on.a.01'), Synset('on.a.02'), Synset('along.r.01'), Synset('on.r.02'), Synset('on.r.03')]
# [Synset('life.n.02'), Synset('living.n.02'), Synset('animation.n.01'), Synset('support.n.06'), Synset('populate.v.01'), Synset('live.v.02'), Synset('survive.v.01'), Synset('exist.v.02'), Synset('be.v.11'), Synset('know.v.05'), Synset('live.v.07'), Synset('living.a.01'), Synset('living.s.02'), Synset('living.s.03'), Synset('surviving.s.01'), Synset('living.s.05'), Synset('living.s.06')]
# [Synset('iodine.n.01'), Synset('one.n.01'), Synset('i.n.03'), Synset('one.s.01')]
# []
# [Synset('beryllium.n.01'), Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('giant.n.04'), Synset('whale.n.02'), Synset('whale.v.01')]
# [Synset('shark.n.01'), Synset('shark.n.02'), Synset('shark.n.03'), Synset('shark.v.01'), Synset('shark.v.02')]
# []
# [Synset('iodine.n.01'), Synset('one.n.01'), Synset('i.n.03'), Synset('one.s.01')]
# []
# [Synset('not.r.01')]
# [Synset('stop.n.01'), Synset('stop.n.02'), Synset('stop.n.03'), Synset('arrest.n.02'), Synset('stop.n.05'), Synset('stop_consonant.n.01'), Synset('period.n.07'), Synset('stop.n.08'), Synset('diaphragm.n.01'), Synset('catch.n.06'), Synset('blockage.n.02'), Synset('stop.v.01'), Synset('discontinue.v.01'), Synset('stop.v.03'), Synset('stop.v.04'), Synset('stop.v.05'), Synset('break.v.10'), Synset('check.v.18'), Synset('intercept.v.01'), Synset('end.v.01'), Synset('barricade.v.01'), Synset('hold_on.v.02')]
# []
# [Synset('death.n.01'), Synset('death.n.02'), Synset('death.n.03'), Synset('death.n.04'), Synset('death.n.05'), Synset('death.n.06'), Synset('end.n.06'), Synset('death.n.08')]
# []
# []
# []
# [Synset('nod.n.01'), Synset('nod.n.02'), Synset('nod.v.01'), Synset('nod.v.02'), Synset('nod.v.03'), Synset('nod.v.04'), Synset('nod.v.05')]
# []
# [Synset('more.n.01'), Synset('more.a.01'), Synset('more.a.02'), Synset('more.r.01'), Synset('more.r.02')]
# [Synset('love.v.01'), Synset('love.v.02'), Synset('love.v.03'), Synset('sleep_together.v.01'), Synset('loving.a.01')]
# [Synset('one.n.01'), Synset('one.n.02'), Synset('one.s.01'), Synset('one.s.02'), Synset('one.s.03'), Synset('one.s.04'), Synset('one.s.05'), Synset('one.s.06'), Synset('matchless.s.01')]
# [Synset('batter.n.01'), Synset('batter.n.02'), Synset('buffet.v.01'), Synset('clobber.v.01'), Synset('dinge.v.01')]
# []
# [Synset('heart.n.01'), Synset('heart.n.02'), Synset('heart.n.03'), Synset('center.n.01'), Synset('kernel.n.03'), Synset('heart.n.06'), Synset('heart.n.07'), Synset('heart.n.08'), Synset('affection.n.01'), Synset('heart.n.10')]
# [Synset('three.n.01'), Synset('trey.n.02'), Synset('three.s.01')]
# []
# [Synset('god.n.01'), Synset('deity.n.01'), Synset('god.n.03'), Synset('idol.n.01')]
# [Synset('holy_place.n.01'), Synset('holy.a.01')]
# [Synset('sonnet.n.01'), Synset('sonnet.v.01'), Synset('sonnet.v.02')]
# [Synset('hamlet.n.01'), Synset('hamlet.n.02'), Synset('village.n.02')]
# [Synset('act.n.01'), Synset('act.n.02'), Synset('act.n.03'), Synset('act.n.04'), Synset('act.n.05'), Synset('act.v.01'), Synset('act.v.02'), Synset('act.v.03'), Synset('act.v.04'), Synset('act.v.05'), Synset('act.v.06'), Synset('work.v.03'), Synset('act.v.08'), Synset('dissemble.v.03'), Synset('act.v.10')]
# [Synset('three.n.01'), Synset('three.s.01')]
# [Synset('scene.n.01'), Synset('scene.n.02'), Synset('view.n.02'), Synset('scene.n.04'), Synset('picture.n.04'), Synset('scene.n.06'), Synset('fit.n.01'), Synset('scene.n.08'), Synset('setting.n.01'), Synset('scenery.n.01')]
# [Synset('iodine.n.01'), Synset('one.n.01'), Synset('i.n.03'), Synset('one.s.01')]
# []
# [Synset('beryllium.n.01'), Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('oregon.n.01'), Synset('operating_room.n.01')]
# [Synset('not.r.01')]
# []
# [Synset('beryllium.n.01'), Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('dream.n.01'), Synset('dream.n.02'), Synset('ambition.n.01'), Synset('pipe_dream.n.01'), Synset('dream.n.05'), Synset('dream.n.06'), Synset('dream.v.01'), Synset('dream.v.02')]
# [Synset('subject.n.01'), Synset('theme.n.02'), Synset('theme.n.03'), Synset('composition.n.08'), Synset('root.n.03'), Synset('theme.v.01')]
# []
# [Synset('english.n.01'), Synset('english.n.02'), Synset('english.n.03'), Synset('english.n.04'), Synset('english.a.01'), Synset('english.a.02')]
# [Synset('bacillus.n.01'), Synset('b-complex_vitamin.n.01'), Synset('boron.n.01'), Synset('bel.n.01'), Synset('barn.n.02'), Synset('b.n.06'), Synset('b.n.07')]
# [Synset('beloved.n.01'), Synset('lamb.n.04'), Synset('beloved.s.01'), Synset('dear.s.02'), Synset('dear.s.03'), Synset('costly.s.02'), Synset('dearly.r.03'), Synset('dearly.r.02')]
# []
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# [Synset('love.n.01'), Synset('love.n.02'), Synset('beloved.n.01'), Synset('love.n.04'), Synset('love.n.05'), Synset('sexual_love.n.02'), Synset('love.v.01'), Synset('love.v.02'), Synset('love.v.03'), Synset('sleep_together.v.01')]
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('not.r.01')]
# [Synset('all.a.01'), Synset('all.s.02'), Synset('wholly.r.01')]
# [Synset('sonnet.n.01'), Synset('sonnet.v.01'), Synset('sonnet.v.02')]
# [Synset('thirty.n.01'), Synset('xxx.n.02'), Synset('thirty.s.01')]
# []
# [Synset('creation.n.01'), Synset('creation.n.02'), Synset('creation.n.03'), Synset('initiation.n.02'), Synset('creation.n.05'), Synset('universe.n.01')]
# []
# [Synset('black.n.05'), Synset('negro.s.01')]
# [Synset('talk.v.02'), Synset('talk.v.01'), Synset('speak.v.03'), Synset('address.v.02'), Synset('speak.v.05')]
# []
# [Synset('river.n.01')]
# []
# [Synset('feeling.n.01'), Synset('impression.n.01'), Synset('spirit.n.02'), Synset('feeling.n.04'), Synset('touch.n.10'), Synset('feeling.n.06'), Synset('feel.v.01'), Synset('find.v.05'), Synset('feel.v.03'), Synset('feel.v.04'), Synset('feel.v.05'), Synset('feel.v.06'), Synset('feel.v.07'), Synset('feel.v.08'), Synset('feel.v.09'), Synset('palpate.v.01'), Synset('feel.v.11'), Synset('feel.v.12'), Synset('feel.v.13')]
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('first.n.01'), Synset('first.n.02'), Synset('beginning.n.02'), Synset('first_base.n.02'), Synset('first.n.05'), Synset('first_gear.n.01'), Synset('first.a.01'), Synset('first.s.02'), Synset('inaugural.s.02'), Synset('beginning.s.01'), Synset('first.s.05'), Synset('first.a.06'), Synset('first.r.01'), Synset('first.r.02'), Synset('first.r.03'), Synset('foremost.r.01')]
# [Synset('dream.n.01'), Synset('dream.n.02'), Synset('ambition.n.01'), Synset('pipe_dream.n.01'), Synset('dream.n.05'), Synset('dream.n.06'), Synset('dream.v.01'), Synset('dream.v.02')]
# [Synset('variation.n.01'), Synset('variation.n.02'), Synset('variation.n.03'), Synset('version.n.02'), Synset('variation.n.05'), Synset('magnetic_declination.n.01'), Synset('variation.n.07'), Synset('variation.n.08'), Synset('mutant.n.01'), Synset('pas_seul.n.01'), Synset('variation.n.11')]
# [Synset('iodine.n.01'), Synset('one.n.01'), Synset('i.n.03'), Synset('one.s.01')]
# [Synset('roll.v.12'), Synset('cheat_on.v.01'), Synset('wander.v.03'), Synset('weave.v.04'), Synset('digress.v.01')]
# [Synset('alone.s.02'), Synset('lonely.s.02'), Synset('lone.s.02'), Synset('lonely.s.04')]
# [Synset('arsenic.n.02'), Synset('american_samoa.n.01'), Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07'), Synset('equally.r.01')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('cloud.n.01'), Synset('cloud.n.02'), Synset('cloud.n.03'), Synset('cloud.n.04'), Synset('cloud.n.05'), Synset('swarm.n.02'), Synset('overcast.v.01'), Synset('obscure.v.01'), Synset('cloud.v.03'), Synset('cloud.v.04'), Synset('defile.v.01'), Synset('cloud.v.06'), Synset('mottle.v.02'), Synset('cloud.v.08')]
# [Synset('somewhere.n.01'), Synset('somewhere.r.01')]
# [Synset('iodine.n.01'), Synset('one.n.01'), Synset('i.n.03'), Synset('one.s.01')]
# [Synset('rich_person.n.01'), Synset('have.v.01'), Synset('have.v.02'), Synset('experience.v.03'), Synset('own.v.01'), Synset('get.v.03'), Synset('consume.v.02'), Synset('have.v.07'), Synset('hold.v.03'), Synset('have.v.09'), Synset('have.v.10'), Synset('have.v.11'), Synset('have.v.12'), Synset('induce.v.02'), Synset('accept.v.02'), Synset('receive.v.01'), Synset('suffer.v.02'), Synset('have.v.17'), Synset('give_birth.v.01'), Synset('take.v.35')]
# [Synset('never.r.01'), Synset('never.r.02')]
# []
# [Synset('beyond.r.01'), Synset('beyond.r.02'), Synset('beyond.r.03')]
# [Synset('poem.n.01')]
# []
# [Synset('turner.n.01'), Synset('turner.n.02'), Synset('turner.n.03'), Synset('turner.n.04'), Synset('turner.n.05'), Synset('turner.n.06'), Synset('turner.n.07'), Synset('turner.n.08')]
# [Synset('hour_angle.n.02'), Synset('have.v.01'), Synset('have.v.02'), Synset('experience.v.03'), Synset('own.v.01'), Synset('get.v.03'), Synset('consume.v.02'), Synset('have.v.07'), Synset('hold.v.03'), Synset('have.v.09'), Synset('have.v.10'), Synset('have.v.11'), Synset('have.v.12'), Synset('induce.v.02'), Synset('accept.v.02'), Synset('receive.v.01'), Synset('suffer.v.02'), Synset('have.v.17'), Synset('give_birth.v.01'), Synset('take.v.35')]
# [Synset('collapse.v.01'), Synset('break_down.v.08'), Synset('collapse.v.03'), Synset('crumble.v.01'), Synset('collapse.v.05'), Synset('crack_up.v.01'), Synset('collapse.v.07')]
# []
# [Synset('wish.n.01'), Synset('wish.n.02'), Synset('regard.n.03'), Synset('wish.n.04'), Synset('wish.v.01'), Synset('wish.v.02'), Synset('wish.v.03'), Synset('wish.v.04'), Synset('wish.v.05'), Synset('wish.v.06')]
# []
# []
# [Synset('fabric.n.01')]
# []
# [Synset('eden.n.01'), Synset('heaven.n.02')]
# [Synset('beryllium.n.01'), Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('gladiolus.n.01'), Synset('glad.a.01'), Synset('glad.s.02'), Synset('glad.s.03'), Synset('beaming.s.01')]
# []
# [Synset('nose.n.01'), Synset('nose.n.02'), Synset('nose.n.03'), Synset('nose.n.04'), Synset('nose.n.05'), Synset('nose.n.06'), Synset('nose.n.07'), Synset('nozzle.n.01'), Synset('intrude.v.03'), Synset('nose.v.02'), Synset('scent.v.02'), Synset('nose.v.04'), Synset('nuzzle.v.02'), Synset('nose.v.06')]
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('on.a.01'), Synset('on.a.02'), Synset('along.r.01'), Synset('on.r.02'), Synset('on.r.03')]
# []
# [Synset('face.n.01'), Synset('expression.n.01'), Synset('face.n.03'), Synset('face.n.04'), Synset('face.n.05'), Synset('side.n.04'), Synset('face.n.07'), Synset('face.n.08'), Synset('grimace.n.01'), Synset('font.n.01'), Synset('face.n.11'), Synset('boldness.n.02'), Synset('face.n.13'), Synset('confront.v.02'), Synset('confront.v.01'), Synset('front.v.01'), Synset('face.v.04'), Synset('face.v.05'), Synset('confront.v.03'), Synset('face.v.07'), Synset('face.v.08'), Synset('face.v.09')]
# []
# [Synset('cry.n.01'), Synset('cry.n.02'), Synset('war_cry.n.01'), Synset('cry.n.04'), Synset('cry.n.05'), Synset('shout.v.02'), Synset('cry.v.02'), Synset('exclaim.v.01'), Synset('cry.v.04'), Synset('cry.v.05'), Synset('cry.v.06'), Synset('cry.v.07')]
# []
# []
# [Synset('cicada.n.01')]
# [Synset('life.n.01'), Synset('life.n.02'), Synset('life.n.03'), Synset('animation.n.01'), Synset('life.n.05'), Synset('life.n.06'), Synset('life.n.07'), Synset('life.n.08'), Synset('liveliness.n.02'), Synset('life.n.10'), Synset('life.n.11'), Synset('biography.n.01'), Synset('life.n.13'), Synset('life_sentence.n.01')]
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('fine.n.01'), Synset('ticket.v.01'), Synset('all_right.s.01'), Synset('fine.s.02'), Synset('fine.s.03'), Synset('fine.s.04'), Synset('fine.a.05'), Synset('fine.s.06'), Synset('very_well.r.02'), Synset('finely.r.03')]
# [Synset('astatine.n.01'), Synset('at.n.02')]
# []
# [Synset('menagerie.n.02')]
# [Synset('haunt.v.01'), Synset('haunt.v.02'), Synset('frequent.v.02'), Synset('haunted.s.01'), Synset('haunted.s.02'), Synset('haunted.s.03')]
# [Synset('house.n.01'), Synset('firm.n.01'), Synset('house.n.03'), Synset('house.n.04'), Synset('house.n.05'), Synset('house.n.06'), Synset('house.n.07'), Synset('sign_of_the_zodiac.n.01'), Synset('house.n.09'), Synset('family.n.01'), Synset('theater.n.01'), Synset('house.n.12'), Synset('house.v.01'), Synset('house.v.02')]
# [Synset('paul.n.01'), Synset('paul.n.02')]
# [Synset('revere.n.01'), Synset('revers.n.01'), Synset('idolize.v.01'), Synset('reverence.v.01')]
# [Synset('drive.n.08'), Synset('ride.n.02'), Synset('ride.v.01'), Synset('ride.v.02'), Synset('ride.v.03'), Synset('ride.v.04'), Synset('tease.v.02'), Synset('ride.v.06'), Synset('drive.v.12'), Synset('depend_on.v.01'), Synset('ride.v.09'), Synset('ride.v.10'), Synset('ride.v.11'), Synset('ride.v.12'), Synset('ride.v.13'), Synset('ride.v.14')]
# [Synset('halloween.n.01')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('small.n.01'), Synset('small.n.02'), Synset('small.a.01'), Synset('minor.s.10'), Synset('little.s.03'), Synset('small.s.04'), Synset('humble.s.01'), Synset('little.s.07'), Synset('little.s.05'), Synset('small.s.08'), Synset('modest.s.02'), Synset('belittled.s.01'), Synset('small.r.01')]
# [Synset('needed.s.01')]
# [Synset('fact.n.01'), Synset('fact.n.02'), Synset('fact.n.03'), Synset('fact.n.04')]
# [Synset('fern.n.01')]
# [Synset('hill.n.01'), Synset('mound.n.04'), Synset('hill.n.03'), Synset('hill.n.04'), Synset('mound.n.01'), Synset('hill.v.01')]
# []
# [Synset('moon.n.01'), Synset('moon.n.02'), Synset('lunar_month.n.01'), Synset('moonlight.n.01'), Synset('moon.n.05'), Synset('moon.n.06'), Synset('daydream.v.02'), Synset('moon.v.02'), Synset('moon.v.03')]
# [Synset('rose.n.01'), Synset('blush_wine.n.01'), Synset('rose.n.03'), Synset('rise.v.01'), Synset('rise.v.02'), Synset('arise.v.03'), Synset('rise.v.04'), Synset('surface.v.01'), Synset('originate.v.01'), Synset('ascend.v.08'), Synset('wax.v.02'), Synset('heighten.v.01'), Synset('get_up.v.02'), Synset('rise.v.11'), Synset('rise.v.12'), Synset('rise.v.13'), Synset('rebel.v.01'), Synset('rise.v.15'), Synset('rise.v.16'), Synset('resurrect.v.03'), Synset('rose.s.01')]
# [Synset('over.n.01'), Synset('complete.s.05'), Synset('over.r.01'), Synset('over.r.02'), Synset('over.r.03'), Synset('over.r.04'), Synset('all_over.r.01')]
# []
# [Synset('bay.n.01'), Synset('bay.n.02'), Synset('true_laurel.n.01'), Synset('bay.n.04'), Synset('bay.n.05'), Synset('alcove.n.01'), Synset('bay.n.07'), Synset('bay.v.01'), Synset('bay.v.02'), Synset('bay.s.01')]
# [Synset('iodine.n.01'), Synset('one.n.01'), Synset('i.n.03'), Synset('one.s.01')]
# [Synset('have.v.01'), Synset('have.v.02'), Synset('experience.v.03'), Synset('own.v.01'), Synset('get.v.03'), Synset('consume.v.02'), Synset('have.v.07'), Synset('hold.v.03'), Synset('have.v.09'), Synset('have.v.10'), Synset('have.v.11'), Synset('have.v.12'), Synset('induce.v.02'), Synset('accept.v.02'), Synset('receive.v.01'), Synset('suffer.v.02'), Synset('have.v.17'), Synset('give_birth.v.01'), Synset('take.v.35')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('batch.n.02'), Synset('lot.n.02'), Synset('set.n.05'), Synset('fortune.n.04'), Synset('draw.n.04'), Synset('bunch.n.03'), Synset('lot.n.07'), Synset('lot.v.01'), Synset('distribute.v.01')]
# []
# [Synset('feelings.n.01'), Synset('feeling.n.01'), Synset('impression.n.01'), Synset('spirit.n.02'), Synset('feeling.n.04'), Synset('touch.n.10'), Synset('feeling.n.06'), Synset('feel.v.01'), Synset('find.v.05'), Synset('feel.v.03'), Synset('feel.v.04'), Synset('feel.v.05'), Synset('feel.v.06'), Synset('feel.v.07'), Synset('feel.v.08'), Synset('feel.v.09'), Synset('palpate.v.01'), Synset('feel.v.11'), Synset('feel.v.12'), Synset('feel.v.13')]
# [Synset('christmas.n.01'), Synset('christmas.n.02')]
# [Synset('bell.n.01'), Synset('doorbell.n.01'), Synset('bell.n.03'), Synset('bell.n.04'), Synset('bell.n.05'), Synset('bell.n.06'), Synset('bell.n.07'), Synset('bell.n.08'), Synset('chime.n.01'), Synset('bell.n.10'), Synset('bell.v.01')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# []
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('hydrogen.n.01'), Synset('henry.n.01'), Synset('planck's_constant.n.01'), Synset('h.n.04'), Synset('heat_content.n.01')]
# [Synset('hydrogen.n.01'), Synset('henry.n.01'), Synset('planck's_constant.n.01'), Synset('h.n.04'), Synset('heat_content.n.01')]
# []
# [Synset('universe.n.01'), Synset('world.n.02'), Synset('world.n.03'), Synset('earth.n.01'), Synset('populace.n.01'), Synset('world.n.06'), Synset('worldly_concern.n.01'), Synset('world.n.08'), Synset('global.s.01')]
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('beautiful.a.01'), Synset('beautiful.s.02')]
# []
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('time.n.01'), Synset('time.n.02'), Synset('time.n.03'), Synset('time.n.04'), Synset('time.n.05'), Synset('time.n.06'), Synset('clock_time.n.01'), Synset('fourth_dimension.n.01'), Synset('meter.n.04'), Synset('prison_term.n.01'), Synset('clock.v.01'), Synset('time.v.02'), Synset('time.v.03'), Synset('time.v.04'), Synset('time.v.05')]
# []
# [Synset('talk.n.01'), Synset('talk.n.02'), Synset('talk.n.03'), Synset('lecture.n.01'), Synset('talk.n.05'), Synset('talk.v.01'), Synset('talk.v.02'), Synset('speak.v.03'), Synset('spill.v.05'), Synset('spill_the_beans.v.01'), Synset('lecture.v.01')]
# [Synset('mister.n.01')]
# []
# [Synset('jack.n.01'), Synset('mariner.n.01'), Synset('laborer.n.01'), Synset('jackfruit.n.02'), Synset('jack.n.05'), Synset('jack.n.06'), Synset('jack.n.07'), Synset('jack.n.08'), Synset('jack.n.09'), Synset('jack.n.10'), Synset('jack.n.11'), Synset('jack.n.12'), Synset('jack.v.01'), Synset('jacklight.v.01')]
# []
# [Synset('center.n.01'), Synset('middle.n.02'), Synset('middle.n.03'), Synset('middle.n.04'), Synset('middle.v.01'), Synset('in-between.s.01'), Synset('center.s.01'), Synset('middle.a.03'), Synset('middle.a.04')]
# [Synset('passage.n.01'), Synset('passage.n.02'), Synset('passage.n.03'), Synset('enactment.n.01'), Synset('passage.n.05'), Synset('passage.n.06'), Synset('passage.n.07'), Synset('passage.n.08'), Synset('passing.n.03'), Synset('passage.n.10')]
# [Synset('one.n.01'), Synset('one.n.02'), Synset('one.s.01'), Synset('one.s.02'), Synset('one.s.03'), Synset('one.s.04'), Synset('one.s.05'), Synset('one.s.06'), Synset('matchless.s.01')]
# [Synset('sister.n.01'), Synset('sister.n.02'), Synset('sister.n.03'), Synset('baby.n.05')]
# [Synset('rich_person.n.01'), Synset('have.v.01'), Synset('have.v.02'), Synset('experience.v.03'), Synset('own.v.01'), Synset('get.v.03'), Synset('consume.v.02'), Synset('have.v.07'), Synset('hold.v.03'), Synset('have.v.09'), Synset('have.v.10'), Synset('have.v.11'), Synset('have.v.12'), Synset('induce.v.02'), Synset('accept.v.02'), Synset('receive.v.01'), Synset('suffer.v.02'), Synset('have.v.17'), Synset('give_birth.v.01'), Synset('take.v.35')]
# [Synset('iodine.n.01'), Synset('one.n.01'), Synset('i.n.03'), Synset('one.s.01')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# []
# [Synset('house.n.01'), Synset('firm.n.01'), Synset('house.n.03'), Synset('house.n.04'), Synset('house.n.05'), Synset('house.n.06'), Synset('house.n.07'), Synset('sign_of_the_zodiac.n.01'), Synset('house.n.09'), Synset('family.n.01'), Synset('theater.n.01'), Synset('house.n.12'), Synset('house.v.01'), Synset('house.v.02')]
# [Synset('thanksgiving.n.01'), Synset('grace.n.06')]
# [Synset('day.n.01'), Synset('day.n.02'), Synset('day.n.03'), Synset('day.n.04'), Synset('day.n.05'), Synset('day.n.06'), Synset('day.n.07'), Synset('sidereal_day.n.01'), Synset('day.n.09'), Synset('day.n.10')]
# [Synset('dream.n.01'), Synset('dream.n.02'), Synset('ambition.n.01'), Synset('pipe_dream.n.01'), Synset('dream.n.05'), Synset('dream.n.06'), Synset('dream.v.01'), Synset('dream.v.02')]
# [Synset('song.n.01'), Synset('song.n.02'), Synset('song.n.03'), Synset('birdcall.n.01'), Synset('song.n.05'), Synset('sung.n.01')]
# []
# [Synset('poem.n.01')]
# [Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('dream.n.01'), Synset('dream.n.02'), Synset('ambition.n.01'), Synset('pipe_dream.n.01'), Synset('dream.n.05'), Synset('dream.n.06'), Synset('dream.v.01'), Synset('dream.v.02')]
# [Synset('relation.n.04'), Synset('telling.n.02'), Synset('tattle.n.01'), Synset('state.v.01'), Synset('tell.v.02'), Synset('tell.v.03'), Synset('order.v.01'), Synset('tell.v.05'), Synset('assure.v.02'), Synset('tell.v.07'), Synset('distinguish.v.01'), Synset('revealing.s.01'), Synset('cogent.s.01'), Synset('impressive.s.02')]
# []
# [Synset('information_technology.n.01')]
# [Synset('time.n.01'), Synset('time.n.02'), Synset('time.n.03'), Synset('time.n.04'), Synset('time.n.05'), Synset('time.n.06'), Synset('clock_time.n.01'), Synset('fourth_dimension.n.01'), Synset('meter.n.04'), Synset('prison_term.n.01'), Synset('clock.v.01'), Synset('time.v.02'), Synset('time.v.03'), Synset('time.v.04'), Synset('time.v.05')]
# [Synset('thanksgiving.n.01'), Synset('grace.n.06')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('brief.n.01'), Synset('brief.n.02'), Synset('brief.v.01'), Synset('brief.s.01'), Synset('brief.s.02'), Synset('abbreviated.s.01')]
# [Synset('history.n.01'), Synset('history.n.02'), Synset('history.n.03'), Synset('history.n.04'), Synset('history.n.05')]
# []
# [Synset('hostility.n.01'), Synset('hostility.n.02'), Synset('hostility.n.03'), Synset('aggression.n.03')]
# []
# []
# [Synset('people.n.01'), Synset('citizenry.n.01'), Synset('people.n.03'), Synset('multitude.n.03'), Synset('people.v.01'), Synset('people.v.02')]
# [Synset('immunize.v.02'), Synset('immunized.s.01')]
# []
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('narrative.n.01'), Synset('fib.n.01')]
# []
# []
# []
# []
# [Synset('virgin.n.01'), Synset('virgo.n.01'), Synset('virgo.n.03')]
# []
# [Synset('brand.n.02'), Synset('shuffle.n.01'), Synset('make.v.01'), Synset('make.v.02'), Synset('make.v.03'), Synset('induce.v.02'), Synset('cause.v.01'), Synset('produce.v.02'), Synset('draw.v.04'), Synset('make.v.08'), Synset('create.v.05'), Synset('gain.v.08'), Synset('do.v.08'), Synset('form.v.02'), Synset('reach.v.07'), Synset('make.v.14'), Synset('make.v.15'), Synset('make.v.16'), Synset('construct.v.01'), Synset('make.v.18'), Synset('make.v.19'), Synset('name.v.03'), Synset('have.v.17'), Synset('reach.v.01'), Synset('lay_down.v.01'), Synset('make.v.24'), Synset('make.v.25'), Synset('hold.v.03'), Synset('make.v.27'), Synset('take.v.27'), Synset('stool.v.04'), Synset('make.v.30'), Synset('make.v.31'), Synset('make.v.32'), Synset('make.v.33'), Synset('make.v.34'), Synset('make.v.35'), Synset('make.v.36'), Synset('make.v.37'), Synset('make.v.38'), Synset('cook.v.02'), Synset('seduce.v.01'), Synset('make.v.41'), Synset('make.v.42'), Synset('make.v.43'), Synset('make.v.44'), Synset('make.v.45'), Synset('make.v.46'), Synset('make.v.47'), Synset('make.v.48'), Synset('make.v.49')]
# [Synset('much.n.01'), Synset('much.a.01'), Synset('much.r.01'), Synset('much.r.02'), Synset('a_lot.r.01'), Synset('much.r.04'), Synset('much.r.05')]
# []
# [Synset('time.n.01'), Synset('time.n.02'), Synset('time.n.03'), Synset('time.n.04'), Synset('time.n.05'), Synset('time.n.06'), Synset('clock_time.n.01'), Synset('fourth_dimension.n.01'), Synset('meter.n.04'), Synset('prison_term.n.01'), Synset('clock.v.01'), Synset('time.v.02'), Synset('time.v.03'), Synset('time.v.04'), Synset('time.v.05')]
# []
# [Synset('new.a.01'), Synset('fresh.s.04'), Synset('raw.s.12'), Synset('new.s.04'), Synset('new.s.05'), Synset('new.a.06'), Synset('newfangled.s.01'), Synset('new.s.08'), Synset('modern.s.05'), Synset('new.s.10'), Synset('new.s.11'), Synset('newly.r.01')]
# [Synset('giant.n.05'), Synset('colossus.n.02')]
# [Synset('september.n.01')]
# [Synset('leda.n.01')]
# []
# []
# [Synset('swan.n.01'), Synset('affirm.v.02'), Synset('roll.v.12'), Synset('swan.v.03')]
# []
# [Synset('unknown.n.01'), Synset('stranger.n.01'), Synset('unknown.n.03'), Synset('unknown.a.01'), Synset('nameless.s.01'), Synset('unknown.s.03'), Synset('obscure.s.04'), Synset('strange.s.02')]
# [Synset('citizen.n.01')]
# []
# [Synset('death.n.01'), Synset('death.n.02'), Synset('death.n.03'), Synset('death.n.04'), Synset('death.n.05'), Synset('death.n.06'), Synset('end.n.06'), Synset('death.n.08')]
# []
# [Synset('rich_person.n.01'), Synset('have.v.01'), Synset('have.v.02'), Synset('experience.v.03'), Synset('own.v.01'), Synset('get.v.03'), Synset('consume.v.02'), Synset('have.v.07'), Synset('hold.v.03'), Synset('have.v.09'), Synset('have.v.10'), Synset('have.v.11'), Synset('have.v.12'), Synset('induce.v.02'), Synset('accept.v.02'), Synset('receive.v.01'), Synset('suffer.v.02'), Synset('have.v.17'), Synset('give_birth.v.01'), Synset('take.v.35')]
# [Synset('no.n.01'), Synset('nobelium.n.01'), Synset('no.a.01'), Synset('no.r.01'), Synset('no.r.02'), Synset('no.r.03')]
# [Synset('dominion.n.01'), Synset('district.n.01'), Synset('dominion.n.03')]
# [Synset('on.a.01'), Synset('on.a.02'), Synset('along.r.01'), Synset('on.r.02'), Synset('on.r.03')]
# [Synset('love.n.01'), Synset('love.n.02'), Synset('beloved.n.01'), Synset('love.n.04'), Synset('love.n.05'), Synset('sexual_love.n.02'), Synset('love.v.01'), Synset('love.v.02'), Synset('love.v.03'), Synset('sleep_together.v.01')]
# [Synset('diving.n.01'), Synset('dive.n.02'), Synset('dive.v.01'), Synset('dive.v.02'), Synset('dive.v.03')]
# []
# []
# [Synset('wreck.n.01'), Synset('shipwreck.n.03'), Synset('crash.n.02'), Synset('wreck.n.04'), Synset('bust_up.v.01')]
# []
# [Synset('brand.n.02'), Synset('shuffle.n.01'), Synset('make.v.01'), Synset('make.v.02'), Synset('make.v.03'), Synset('induce.v.02'), Synset('cause.v.01'), Synset('produce.v.02'), Synset('draw.v.04'), Synset('make.v.08'), Synset('create.v.05'), Synset('gain.v.08'), Synset('do.v.08'), Synset('form.v.02'), Synset('reach.v.07'), Synset('make.v.14'), Synset('make.v.15'), Synset('make.v.16'), Synset('construct.v.01'), Synset('make.v.18'), Synset('make.v.19'), Synset('name.v.03'), Synset('have.v.17'), Synset('reach.v.01'), Synset('lay_down.v.01'), Synset('make.v.24'), Synset('make.v.25'), Synset('hold.v.03'), Synset('make.v.27'), Synset('take.v.27'), Synset('stool.v.04'), Synset('make.v.30'), Synset('make.v.31'), Synset('make.v.32'), Synset('make.v.33'), Synset('make.v.34'), Synset('make.v.35'), Synset('make.v.36'), Synset('make.v.37'), Synset('make.v.38'), Synset('cook.v.02'), Synset('seduce.v.01'), Synset('make.v.41'), Synset('make.v.42'), Synset('make.v.43'), Synset('make.v.44'), Synset('make.v.45'), Synset('make.v.46'), Synset('make.v.47'), Synset('make.v.48'), Synset('make.v.49')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('prairie.n.01')]
# [Synset('kindness.n.01'), Synset('forgivingness.n.01'), Synset('kindness.n.03')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('christmas.n.01'), Synset('christmas.n.02')]
# [Synset('carol.n.01'), Synset('carol.n.02'), Synset('carol.v.01')]
# []
# [Synset('power.n.01'), Synset('power.n.02'), Synset('ability.n.02'), Synset('office.n.04'), Synset('power.n.05'), Synset('exponent.n.03'), Synset('might.n.01'), Synset('world_power.n.01'), Synset('baron.n.03'), Synset('power.v.01')]
# []
# []
# [Synset('dog.n.01'), Synset('frump.n.01'), Synset('dog.n.03'), Synset('cad.n.01'), Synset('frank.n.02'), Synset('pawl.n.01'), Synset('andiron.n.01'), Synset('chase.v.01')]
# [Synset('on.a.01'), Synset('on.a.02'), Synset('along.r.01'), Synset('on.r.02'), Synset('on.r.03')]
# [Synset('joy.n.01'), Synset('joy.n.02'), Synset('rejoice.v.01'), Synset('gladden.v.01')]
# []
# [Synset('sorrow.n.01'), Synset('sorrow.n.02'), Synset('grief.n.02'), Synset('sadness.n.02'), Synset('grieve.v.01')]
# [Synset('coherence.n.01'), Synset('coherence.n.02')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# [Synset('consequence.n.01'), Synset('consequence.n.02'), Synset('consequence.n.03')]
# []
# [Synset('ice.n.01'), Synset('ice.n.02'), Synset('ice.n.03'), Synset('frosting.n.01'), Synset('ice.n.05'), Synset('methamphetamine.n.01'), Synset('internal-combustion_engine.n.01'), Synset('ice_rink.n.01'), Synset('frost.v.01'), Synset('ice.v.02'), Synset('ice.v.03')]
# [Synset('cream.n.01'), Synset('cream.n.02'), Synset('cream.n.03'), Synset('cream.v.01'), Synset('cream.v.02'), Synset('cream.v.03'), Synset('skim.v.06'), Synset('cream.v.05')]
# [Synset('lashkar-e-taiba.n.01'), Synset('let.n.02'), Synset('let.v.01'), Synset('let.v.02'), Synset('permit.v.01'), Synset('get.v.03'), Synset('let.v.05'), Synset('lease.v.03')]
# []
# [Synset('not.r.01')]
# [Synset('say.n.01'), Synset('state.v.01'), Synset('allege.v.01'), Synset('suppose.v.01'), Synset('read.v.02'), Synset('order.v.01'), Synset('pronounce.v.01'), Synset('say.v.07'), Synset('say.v.08'), Synset('say.v.09'), Synset('say.v.10'), Synset('say.v.11')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# []
# [Synset('ring.n.01'), Synset('ring.n.02'), Synset('hoop.n.02'), Synset('closed_chain.n.01'), Synset('gang.n.01'), Synset('ring.n.06'), Synset('ring.n.07'), Synset('ring.n.08'), Synset('band.n.12'), Synset('ring.v.01'), Synset('resound.v.01'), Synset('ring.v.03'), Synset('call.v.03'), Synset('surround.v.01'), Synset('ring.v.06')]
# [Synset('out.n.01'), Synset('come_out_of_the_closet.v.01'), Synset('out.v.02'), Synset('out.v.03'), Synset('out.a.01'), Synset('extinct.s.03'), Synset('out.s.03'), Synset('out.s.04'), Synset('forbidden.s.01'), Synset('out.s.06'), Synset('out.s.07'), Synset('out.s.08'), Synset('out.s.09'), Synset('knocked_out.s.01'), Synset('out.r.01'), Synset('out.r.02'), Synset('away.r.02')]
# [Synset('wild.n.01'), Synset('wilderness.n.03'), Synset('wild.a.01'), Synset('wild.a.02'), Synset('wild.s.03'), Synset('wild.s.04'), Synset('violent.s.03'), Synset('baseless.s.01'), Synset('raving_mad.s.01'), Synset('hazardous.s.01'), Synset('fantastic.s.03'), Synset('godforsaken.s.01'), Synset('crazy.s.05'), Synset('barbarian.s.01'), Synset('angry.s.02'), Synset('rampantly.r.01'), Synset('wild.r.02')]
# [Synset('bell.n.01'), Synset('doorbell.n.01'), Synset('bell.n.03'), Synset('bell.n.04'), Synset('bell.n.05'), Synset('bell.n.06'), Synset('bell.n.07'), Synset('bell.n.08'), Synset('chime.n.01'), Synset('bell.n.10'), Synset('bell.v.01')]
# [Synset('one.n.01'), Synset('one.n.02'), Synset('one.s.01'), Synset('one.s.02'), Synset('one.s.03'), Synset('one.s.04'), Synset('one.s.05'), Synset('one.s.06'), Synset('matchless.s.01')]
# [Synset('today.n.01'), Synset('today.n.02'), Synset('nowadays.r.01'), Synset('today.r.02')]
# []
# [Synset('iodine.n.01'), Synset('one.n.01'), Synset('i.n.03'), Synset('one.s.01')]
# [Synset('americium.n.01'), Synset('master_of_arts.n.01'), Synset('amplitude_modulation.n.01'), Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('song.n.01'), Synset('song.n.02'), Synset('song.n.03'), Synset('birdcall.n.01'), Synset('song.n.05'), Synset('sung.n.01')]
# []
# []
# []
# []
# ...
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# [Synset('house.n.01'), Synset('firm.n.01'), Synset('house.n.03'), Synset('house.n.04'), Synset('house.n.05'), Synset('house.n.06'), Synset('house.n.07'), Synset('sign_of_the_zodiac.n.01'), Synset('house.n.09'), Synset('family.n.01'), Synset('theater.n.01'), Synset('house.n.12'), Synset('house.v.01'), Synset('house.v.02')]
# []
# []
# [Synset('sea.n.01'), Synset('ocean.n.02'), Synset('sea.n.03')]
# [Synset('uneasy.a.01'), Synset('restless.a.03'), Synset('anxious.s.02'), Synset('awkward.s.06'), Synset('uneasy.s.05')]
# []
# [Synset('wave.n.01'), Synset('wave.n.02'), Synset('wave.n.03'), Synset('wave.n.04'), Synset('wave.n.05'), Synset('wave.n.06'), Synset('wave.n.07'), Synset('wave.n.08'), Synset('wave.n.09'), Synset('beckon.v.01'), Synset('brandish.v.01'), Synset('roll.v.11'), Synset('curl.v.04'), Synset('wave.v.05')]
# [Synset('apostrophe.n.01'), Synset('apostrophe.n.02')]
# [Synset('good.n.01'), Synset('good.n.02'), Synset('good.n.03'), Synset('commodity.n.01'), Synset('good.a.01'), Synset('full.s.06'), Synset('good.a.03'), Synset('estimable.s.02'), Synset('beneficial.s.01'), Synset('good.s.06'), Synset('good.s.07'), Synset('adept.s.01'), Synset('good.s.09'), Synset('dear.s.02'), Synset('dependable.s.04'), Synset('good.s.12'), Synset('good.s.13'), Synset('effective.s.04'), Synset('good.s.15'), Synset('good.s.16'), Synset('good.s.17'), Synset('good.s.18'), Synset('good.s.19'), Synset('good.s.20'), Synset('good.s.21'), Synset('well.r.01'), Synset('thoroughly.r.02')]
# [Synset('grief.n.01'), Synset('grief.n.02')]
# []
# [Synset('unite.v.01'), Synset('unify.v.01'), Synset('unite.v.03'), Synset('connect.v.03'), Synset('unite.v.05'), Synset('unite.v.06'), Synset('united.a.01'), Synset('joined.s.01')]
# [Synset('state.n.01'), Synset('state.n.02'), Synset('state.n.03'), Synset('state.n.04'), Synset('state_of_matter.n.01'), Synset('state.n.06'), Synset('country.n.02'), Synset('department_of_state.n.01'), Synset('state.v.01'), Synset('submit.v.02'), Synset('express.v.04')]
# []
# [Synset('montessori.n.01')]
# [Synset('praise.n.01'), Synset('praise.n.02'), Synset('praise.v.01')]
# [Synset('poem.n.01')]
# []
# []
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# [Synset('memory.n.01'), Synset('memory.n.02'), Synset('memory.n.03'), Synset('memory.n.04'), Synset('memory.n.05')]
# []
# [Synset('vitamin_e.n.01'), Synset('einsteinium.n.01'), Synset('east.n.01'), Synset('e.n.04'), Synset('e.n.05')]
# [Synset('meter.n.01'), Synset('molarity.n.01'), Synset('thousand.n.01'), Synset('megabyte.n.01'), Synset('megabyte.n.02'), Synset('m.n.06'), Synset('thousand.s.01')]
# [Synset('elk.n.01'), Synset('wapiti.n.01'), Synset('red_deer.n.01')]
# [Synset('allah.n.01')]
# [Synset('washington.n.02')]
# [Synset('ana.n.01'), Synset('ana.n.02')]
# [Synset('forth.r.02'), Synset('ahead.r.03')]
# [Synset('support.n.06'), Synset('keep.n.02'), Synset('hold.n.07'), Synset('keep.v.01'), Synset('continue.v.01'), Synset('keep.v.03'), Synset('prevent.v.02'), Synset('observe.v.09'), Synset('observe.v.08'), Synset('keep.v.07'), Synset('keep.v.08'), Synset('keep.v.09'), Synset('retain.v.02'), Synset('sustain.v.04'), Synset('keep.v.12'), Synset('observe.v.06'), Synset('restrain.v.01'), Synset('keep.v.15'), Synset('keep.v.16'), Synset('keep_open.v.01'), Synset('keep.v.18'), Synset('keep.v.19'), Synset('keep.v.20'), Synset('keep.v.21'), Synset('preserve.v.04')]
# [Synset('approach.v.01'), Synset('near.a.01'), Synset('near.s.02'), Synset('near.s.03'), Synset('cheeseparing.s.01'), Synset('dear.s.02'), Synset('approximate.s.02'), Synset('near.r.01'), Synset('about.r.07')]
# []
# [Synset('cascades.n.01'), Synset('cascade.n.01'), Synset('cascade.n.02'), Synset('shower.n.04'), Synset('cascade.v.01'), Synset('cascade.v.02')]
# [Synset('write.v.01'), Synset('write.v.02'), Synset('publish.v.03'), Synset('write.v.04'), Synset('write.v.05'), Synset('compose.v.02'), Synset('write.v.07'), Synset('write.v.08'), Synset('spell.v.03'), Synset('write.v.10'), Synset('written.a.01'), Synset('written.a.02'), Synset('scripted.a.01')]
# [Synset('after.s.01'), Synset('subsequently.r.01'), Synset('after.r.02')]
# [Synset('reading.n.01'), Synset('reading.n.02'), Synset('reading.n.03'), Synset('reading.n.04'), Synset('interpretation.n.01'), Synset('reading.n.06'), Synset('recitation.n.02'), Synset('reading.n.08'), Synset('read.v.01'), Synset('read.v.02'), Synset('read.v.03'), Synset('read.v.04'), Synset('read.v.05'), Synset('take.v.06'), Synset('learn.v.04'), Synset('read.v.08'), Synset('read.v.09'), Synset('read.v.10'), Synset('understand.v.03')]
# [Synset('king.n.01'), Synset('king.n.02'), Synset('baron.n.03'), Synset('king.n.04'), Synset('king.n.05'), Synset('king.n.06'), Synset('king.n.07'), Synset('king.n.08'), Synset('king.n.09'), Synset('king.n.10')]
# [Synset('lear.n.01'), Synset('lear.n.02')]
# [Synset('oxygen.n.01'), Synset('o.n.02'), Synset('o.n.03')]
# [Synset('give.n.01'), Synset('give.v.01'), Synset('yield.v.01'), Synset('give.v.03'), Synset('give.v.04'), Synset('give.v.05'), Synset('hold.v.03'), Synset('give.v.07'), Synset('give.v.08'), Synset('give.v.09'), Synset('give.v.10'), Synset('render.v.04'), Synset('impart.v.01'), Synset('establish.v.05'), Synset('give.v.14'), Synset('give.v.15'), Synset('sacrifice.v.01'), Synset('pass.v.05'), Synset('give.v.18'), Synset('give.v.19'), Synset('give.v.20'), Synset('give.v.21'), Synset('grant.v.05'), Synset('move_over.v.01'), Synset('feed.v.02'), Synset('contribute.v.02'), Synset('collapse.v.01'), Synset('give.v.27'), Synset('give.v.28'), Synset('give.v.29'), Synset('afford.v.04'), Synset('give.v.31'), Synset('give.v.32'), Synset('give.v.33'), Synset('give.v.34'), Synset('give.v.35'), Synset('give.v.36'), Synset('give.v.37'), Synset('give.v.38'), Synset('give.v.39'), Synset('give.v.40'), Synset('give.v.41'), Synset('give.v.42'), Synset('give.v.43'), Synset('give.v.44')]
# [Synset('maine.n.01')]
# [Synset('strength.n.01'), Synset('military_capability.n.01'), Synset('force.n.03'), Synset('forte.n.01'), Synset('persuasiveness.n.01'), Synset('intensity.n.01'), Synset('potency.n.02'), Synset('strength.n.08'), Synset('lastingness.n.01')]
# []
# [Synset('return.n.06'), Synset('take.n.02'), Synset('take.v.01'), Synset('take.v.02'), Synset('lead.v.01'), Synset('take.v.04'), Synset('assume.v.03'), Synset('take.v.06'), Synset('bring.v.01'), Synset('take.v.08'), Synset('take.v.09'), Synset('choose.v.01'), Synset('accept.v.02'), Synset('fill.v.04'), Synset('consider.v.03'), Synset('necessitate.v.01'), Synset('take.v.15'), Synset('film.v.01'), Synset('remove.v.01'), Synset('consume.v.02'), Synset('take.v.19'), Synset('take.v.20'), Synset('take.v.21'), Synset('assume.v.05'), Synset('accept.v.05'), Synset('take.v.24'), Synset('learn.v.04'), Synset('claim.v.05'), Synset('take.v.27'), Synset('aim.v.01'), Synset('take.v.29'), Synset('carry.v.02'), Synset('lease.v.04'), Synset('subscribe.v.05'), Synset('take.v.33'), Synset('take.v.34'), Synset('take.v.35'), Synset('claim.v.04'), Synset('accept.v.08'), Synset('contain.v.05'), Synset('take.v.39'), Synset('drive.v.16'), Synset('take.v.41'), Synset('contract.v.04')]
# [Synset('information_technology.n.01')]
# [Synset('washington.n.02'), Synset('be.v.01'), Synset('be.v.02'), Synset('be.v.03'), Synset('exist.v.01'), Synset('be.v.05'), Synset('equal.v.01'), Synset('constitute.v.01'), Synset('be.v.08'), Synset('embody.v.02'), Synset('be.v.10'), Synset('be.v.11'), Synset('be.v.12'), Synset('cost.v.01')]
# [Synset('all.a.01'), Synset('all.s.02'), Synset('wholly.r.01')]
# []
# []
# [Synset('midnight.n.01')]
# [Synset('temper.n.02'), Synset('climate.n.02'), Synset('mood.n.03')]
# []
# [Synset('sister.n.01'), Synset('sister.n.02'), Synset('sister.n.03'), Synset('baby.n.05')]
# []
# [Synset('death.n.01'), Synset('death.n.02'), Synset('death.n.03'), Synset('death.n.04'), Synset('death.n.05'), Synset('death.n.06'), Synset('end.n.06'), Synset('death.n.08')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('bed.n.01'), Synset('bed.n.02'), Synset('bed.n.03'), Synset('bed.n.04'), Synset('seam.n.03'), Synset('layer.n.01'), Synset('bed.n.07'), Synset('bed.n.08'), Synset('bed.v.01'), Synset('bed.v.02'), Synset('bed.v.03'), Synset('sleep_together.v.01'), Synset('go_to_bed.v.01')]
# []
# [Synset('fire.n.03'), Synset('flare.v.03'), Synset('flame.v.02'), Synset('flame.v.03')]
# [Synset('oxygen.n.01'), Synset('o.n.02'), Synset('o.n.03')]
# [Synset('sweet.n.01'), Synset('dessert.n.01'), Synset('sweet.n.03'), Synset('sweet.n.04'), Synset('sweetness.n.02'), Synset('sweet.a.01'), Synset('angelic.s.03'), Synset('dulcet.s.02'), Synset('sweet.s.04'), Synset('gratifying.s.01'), Synset('odoriferous.s.03'), Synset('sweet.a.07'), Synset('fresh.a.06'), Synset('fresh.s.09'), Synset('sugared.s.01'), Synset('sweetly.r.01')]
# [Synset('erstwhile.s.01'), Synset('sometime.r.01')]
# []
# [Synset('flatiron.n.01')]
# []
# []
# [Synset('ruin.n.01'), Synset('ruin.n.02'), Synset('dilapidation.n.02'), Synset('ruin.n.04'), Synset('downfall.n.01'), Synset('laying_waste.n.01'), Synset('destroy.v.02'), Synset('ruin.v.02'), Synset('bankrupt.v.01'), Synset('ruin.v.04'), Synset('deflower.v.01'), Synset('ruin.v.06')]
# []
# [Synset('palmyra.n.01')]
# [Synset('inch.n.01'), Synset('indium.n.01'), Synset('indiana.n.01'), Synset('in.s.01'), Synset('in.s.02'), Synset('in.s.03'), Synset('in.r.01')]
# []
# [Synset('hayfield.n.01')]
# []
# [Synset('first.n.01'), Synset('first.n.02'), Synset('beginning.n.02'), Synset('first_base.n.02'), Synset('first.n.05'), Synset('first_gear.n.01'), Synset('first.a.01'), Synset('first.s.02'), Synset('inaugural.s.02'), Synset('beginning.s.01'), Synset('first.s.05'), Synset('first.a.06'), Synset('first.r.01'), Synset('first.r.02'), Synset('first.r.03'), Synset('foremost.r.01')]
# []
# [Synset('stopping_point.n.01'), Synset('last.n.02'), Synset('last.n.03'), Synset('death.n.05'), Synset('last.n.05'), Synset('last.n.06'), Synset('end.n.03'), Synset('last.n.08'), Synset('last.v.01'), Synset('survive.v.01'), Synset('last.s.01'), Synset('last.a.02'), Synset('concluding.s.01'), Synset('last.s.04'), Synset('last.s.05'), Synset('final.s.02'), Synset('last.s.07'), Synset('final.s.03'), Synset('last.s.09'), Synset('last.r.01'), Synset('last.r.02')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('better.n.01'), Synset('bettor.n.01'), Synset('better.n.03'), Synset('better.n.04'), Synset('better.v.01'), Synset('better.v.02'), Synset('better.v.03'), Synset('better.a.01'), Synset('better.a.02'), Synset('better.s.03'), Synset('better.s.04'), Synset('good.a.01'), Synset('full.s.06'), Synset('good.a.03'), Synset('estimable.s.02'), Synset('beneficial.s.01'), Synset('good.s.06'), Synset('good.s.07'), Synset('adept.s.01'), Synset('good.s.09'), Synset('dear.s.02'), Synset('dependable.s.04'), Synset('good.s.12'), Synset('good.s.13'), Synset('effective.s.04'), Synset('good.s.15'), Synset('good.s.16'), Synset('good.s.17'), Synset('good.s.18'), Synset('good.s.19'), Synset('good.s.20'), Synset('good.s.21'), Synset('well.a.01'), Synset('good.s.13'), Synset('well.s.03'), Synset('better.r.01'), Synset('better.r.02'), Synset('well.r.01'), Synset('well.r.02'), Synset('well.r.03'), Synset('well.r.04'), Synset('well.r.05'), Synset('well.r.06'), Synset('well.r.07'), Synset('well.r.08'), Synset('well.r.09'), Synset('well.r.10'), Synset('well.r.11'), Synset('well.r.12'), Synset('well.r.13')]
# [Synset('suffering.n.02'), Synset('woe.n.02')]
# [Synset('disarm.v.01'), Synset('disarm.v.02'), Synset('disarm.v.03')]
# [Synset('desire.n.01'), Synset('desire.n.02'), Synset('desire.n.03'), Synset('desire.v.01'), Synset('hope.v.01'), Synset('desire.v.03')]
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('divertimento.n.01'), Synset('serenade.n.02'), Synset('serenade.v.01')]
# [Synset('resurrection.n.01'), Synset('resurrection.n.02')]
# [Synset('nectar.n.01'), Synset('nectar.n.02'), Synset('ambrosia.n.04')]
# []
# [Synset('blood.n.01'), Synset('blood.n.02'), Synset('rake.n.01'), Synset('lineage.n.01'), Synset('blood.n.05'), Synset('blood.v.01')]
# []
# []
# [Synset('abandon.v.05'), Synset('defect.v.01'), Synset('desert.v.03'), Synset('abandoned.s.01')]
# [Synset('plantation.n.01'), Synset('plantation.n.02'), Synset('grove.n.02')]
# []
# [Synset('washington.n.02')]
# []
# [Synset('angstrom.n.01'), Synset('vitamin_a.n.01'), Synset('deoxyadenosine_monophosphate.n.01'), Synset('adenine.n.01'), Synset('ampere.n.02'), Synset('a.n.06'), Synset('a.n.07')]
# [Synset('spring.n.01'), Synset('spring.n.02'), Synset('spring.n.03'), Synset('spring.n.04'), Synset('give.n.01'), Synset('leap.n.01'), Synset('jump.v.01'), Synset('form.v.03'), Synset('bounce.v.01'), Synset('spring.v.04'), Synset('spring.v.05')]
# [Synset('dirge.n.01')]
# []
# []
# [Synset('preparation.n.01'), Synset('formulation.n.01'), Synset('planning.n.03'), Synset('readiness.n.01'), Synset('preparation.n.05'), Synset('training.n.01'), Synset('homework.n.01'), Synset('cooking.n.01')]
# []
# [Synset('philistine.n.01'), Synset('philistine.n.02'), Synset('philistine.a.01'), Synset('anti-intellectual.s.01')]
# []
# []
# [Synset('extremum.n.02'), Synset('flower.n.03'), Synset('acme.n.01'), Synset('peak.n.04'), Synset('point.n.08'), Synset('vertex.n.02'), Synset('bill.n.09'), Synset('top_out.v.03')]
# []
# []
# [Synset('dissolution.n.01'), Synset('dissolving.n.01'), Synset('profligacy.n.02'), Synset('adjournment.n.01'), Synset('dissolution.n.05')]
# [Synset('unadorned.a.01')]
# []
# [Synset('smile.n.01'), Synset('smile.v.01'), Synset('smile.v.02')]
# []
# []
# [Synset('lashkar-e-taiba.n.01'), Synset('let.n.02'), Synset('let.v.01'), Synset('let.v.02'), Synset('permit.v.01'), Synset('get.v.03'), Synset('let.v.05'), Synset('lease.v.03')]
# []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-808b223c97f7> in <cell line: 7>()
#       9     tit = tit.lower()
#      10     tokenized = word_tokenize(tit)
# ---> 11     pos = contains_proper_noun(tokenized)
#      12
#      13     if len(tokenized) <= 2 or pos:
#
# <ipython-input-26-b0373f31b28b> in contains_proper_noun(tokenized_text)
#       7
#       8     for word in tokenized_text:
# ----> 9         if is_proper_noun(word):
#      10             return True
#      11     return False
#
# <ipython-input-26-b0373f31b28b> in is_proper_noun(word)
#       1 def is_proper_noun(word):
#       2     synsets = wordnet.synsets(word)
# ----> 3     print(synsets)
#       4     return any('noun.proper' in synset.pos() for synset in synsets)
#       5
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     398                 string = string.decode(self.encoding, 'replace')
#     399
# --> 400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
#     402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in _is_master_process(self)
#     307
#     308     def _is_master_process(self):
# --> 309         return os.getpid() == self._master_pid
#     310
#     311     def set_parent(self, parent):
#
# KeyboardInterrupt:

# %%
len(title_data), len(text_data)
# Out:
# (7000, 7000)

# %%
title_data = title_data[:7000]
text_data = text_data[:7000]

# %%
len(text_data), len(title_data)
# Out:
# (7000, 7000)

# %%
poems = []
for sen, tit in zip(text_data, title_data):

    data = {}
    data['Theme'] = tit
    sents = sen.split('.')
    final_keywords = []
    for sent in sents:
        yake = algorithm.extract_keywords(sent)
        keywords = [kw[1] for kw in yake]
        if len(keywords) >= 2:
            final_keywords.append(keywords)

    data['keywords'] = final_keywords
    poems.append(data)
    if len(poems) % 500 == 1:

        json.dump(poems, open('poetry_yake_keywords''.json','w'))

# %% [markdown]
# **Generating Keywords for Dataset 2: News**

# %%
titles = df_2['title']
texts = df_2['text']

# %%
def has_proper_noun(text):
    # Tokenize the text and get part-of-speech tags
    words = word_tokenize(text)
    pos_tags = pos_tag(words)

    # Check if any word is tagged as a proper noun (NNP or NNPS)
    return any(pos == 'NNP' or pos == 'NNPS' for _, pos in pos_tags)

# %%
tokens = []
count = 0
text_data = []
title_data = []
sentences = []

for sen,tit in zip(texts, titles):
    tit = re.sub(r'[^a-zA-Z\s]', '', tit)
    tit = tit.lower()
    tokenized = word_tokenize(tit)
    pos = has_proper_noun(tokenized)

    if len(tokenized) <= 2 or pos:
        continue
    try:

        sen = re.sub(r'[^a-zA-Z\s.]', '', sen)
        sen = sen.lower()
        sen = sen.replace(' NEWLINE', '.')
        token_len = len(sen.split())
        sen_len = len(sen.split('.'))

        if 5<=sen_len<=50:
            count += 1
            tokens.append(token_len)
            text_data.append(sen)
            title_data.append(tit)
            sentences.append(sen_len)
    except:
        continue


print(count)
print('average tokens of story:', np.mean(tokens))
print('average sentences of story:', np.mean(sentences))
print('average tokens per sentence:', np.mean(tokens)/np.mean(sentences))
# Out:
# 15887
# average tokens of story: 57.77856108768175
# average sentences of story: 7.377163718763769
# average tokens per sentence: 7.832083343998772

# %%
len(title_data), len(text_data)
# Out:
# (15887, 15887)

# %%
title_data = title_data[:5000]
text_data = text_data[:5000]

# %%
len(text_data), len(title_data)
# Out:
# (5000, 5000)

# %%
news = []
for sen, tit in zip(text_data, title_data):

    data = {}
    data['Theme'] = tit
    sents = sen.split('.')
    final_keywords = []
    for sent in sents:
        yake = algorithm.extract_keywords(sent)
        keywords = [kw[1] for kw in yake]
        if len(keywords) >= 2:
            final_keywords.append(keywords)

    data['keywords'] = final_keywords
    news.append(data)
    if len(news) % 500 == 1:

        json.dump(news, open('news_yake_keywords''.json','w'))

# %% [markdown]
# **Generating Keywords for Dataset 3: ROC**

# %%
titles = df_3['title']
texts = df_3['text']

# %%
def has_proper_noun(text):
    # Tokenize the text and get part-of-speech tags
    words = word_tokenize(text)
    pos_tags = pos_tag(words)

    # Check if any word is tagged as a proper noun (NNP or NNPS)
    return any(pos == 'NNP' or pos == 'NNPS' for _, pos in pos_tags)

# %%
tokens = []
count = 0
text_data = []
title_data = []
sentences = []

for sen,tit in zip(texts, titles):
    tit = re.sub(r'[^a-zA-Z\s]', '', tit)
    tit = tit.lower()
    tokenized = word_tokenize(tit)
    pos = has_proper_noun(tokenized)

    if len(tokenized) <= 2 or pos:
        continue
    try:

        sen = re.sub(r'[^a-zA-Z\s.]', '', sen)
        sen = sen.lower()
        sen = sen.replace(' NEWLINE', '.')
        token_len = len(sen.split())
        sen_len = len(sen.split('.'))

        if 5<=sen_len<=50:
            count += 1
            tokens.append(token_len)
            text_data.append(sen)
            title_data.append(tit)
            sentences.append(sen_len)
    except:
        continue


print(count)
print('average tokens of story:', np.mean(tokens))
print('average sentences of story:', np.mean(sentences))
print('average tokens per sentence:', np.mean(tokens)/np.mean(sentences))
# Out:
# 14587
# average tokens of story: 44.09350791800919
# average sentences of story: 5.923424967436759
# average tokens per sentence: 7.443921069382559

# %%
len(title_data), len(text_data)
# Out:
# (14587, 14587)

# %%
title_data = title_data[:7000]
text_data = text_data[:7000]

# %%
len(text_data), len(title_data)
# Out:
# (7000, 7000)

# %%
roc = []
for sen, tit in zip(text_data, title_data):

    data = {}
    data['Theme'] = tit
    sents = sen.split('.')
    final_keywords = []
    for sent in sents:
        yake = algorithm.extract_keywords(sent)
        keywords = [kw[1] for kw in yake]
        if len(keywords) >= 2:
            final_keywords.append(keywords)

    data['keywords'] = final_keywords
    roc.append(data)
    if len(roc) % 500 == 1:

        json.dump(roc, open('roc_yake_keywords''.json','w'))
